# %%
import pandas as pd

# %%
carte_pmr_df = pd.read_csv('/home/onyxia/work/hackathon_mobilites_2025/data/Carte PMR RATP.csv', sep =  ";")

# %%
carte_pmr_df
# Out:
#     ligne lettre_station               station facilite_acces_code  \
# 0     NaN              A               Abesses              yellow
# 1     NaN              A      Adrienne Bolland               green
# 2     NaN              A          Aimé Césaire               black
# 3     NaN              A                Alésia              yellow
# 4     NaN              A  Alexandra David-Néel               green
# ..    ...            ...                   ...                 ...
# 538   NaN              V             Vincennes               green
# 539   NaN              V       Vitry-sur-Seine               green
# 540   NaN              V           Volontaires               white
# 541   NaN              V              Voltaire              yellow
# 542   NaN              W                Wagram              yellow
#
#                                         facilite_acces  \
# 0    équipée d'au moins un escalator ou ascenseur s...
# ...
