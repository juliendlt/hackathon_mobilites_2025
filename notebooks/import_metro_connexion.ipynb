# %% [markdown]
# # Imports

# %%
import polars as pl
import unicodedata
import re

# %% [markdown]
# # Read data

# %%
def read_metro_conexion():
    from pathlib import Path
    import os 
    path_nb = Path(os.getcwd())
    print(path_nb)
    data_path = path_nb / '..' / "data"
    fpath = "metro_connexion_corresp_idfm_ref.csv"
    df = pl.read_csv(data_path / fpath)
    return df

# %%
def normalize_column_name(name: str) -> str:
    # Mettre en minuscules
    name = name.lower()
    # Supprimer les accents
    name = unicodedata.normalize("NFKD", name)
    name = name.encode("ascii", "ignore").decode("utf-8")
    # Remplacer tout caractère non a-z par _
    name = re.sub(r'[^a-z]+', '_', name)
    # Retirer les underscores en trop (début/fin)
    name = name.strip('_')
    return name

# %%
df = read_metro_conexion()
df = df.rename({col: normalize_column_name(col) for col in df.columns})
df.head()
# Out:
# /home/onyxia/work/hackathon_mobilites_2025/notebooks
# shape: (5, 10)
# ┌─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬────────┐
# │ href    ┆ provena ┆ destina ┆ station ┆ descrip ┆ ligne_d ┆ ligne_d ┆ id_zone ┆ id_lign ┆ id_lig │
# │ ---     ┆ nce     ┆ tion    ┆ ---     ┆ tion_de ┆ e_prove ┆ e_desti ┆ _arret_ ┆ e_de_de ┆ ne_de_ │
# │ str     ┆ ---     ┆ ---     ┆ str     ┆ taillee ┆ nance   ┆ nation  ┆ icar    ┆ stinati ┆ proven │
# │         ┆ str     ┆ str     ┆         ┆ ---     ┆ ---     ┆ ---     ┆ ---     ┆ on      ┆ ance   │
# │         ┆         ┆         ┆         ┆ str     ┆ str     ┆ str     ┆ i64     ┆ ---     ┆ ---    │
# │         ┆         ┆         ┆         ┆         ┆         ┆         ┆         ┆ str     ┆ str    │
# ╞═════════╪═════════╪═════════╪═════════╪═════════╪═════════╪═════════╪═════════╪═════════╪════════╡
# │ https:/ ┆ Champ   ┆ Mairie  ┆ Alma -  ┆ Via la  ┆ C       ┆ 9       ┆ 42182   ┆ C01379  ┆ C01727 │
# │ /www.me ┆ de      ┆ de Mont ┆ Marceau ┆ station ┆         ┆         ┆         ┆         ┆        │
# │ tro-con ┆ Mars,   ┆ reuil   ┆ Pont de ┆ Alma-Ma ┆         ┆         ┆         ┆         ┆        │
# │ nexion. ┆ Pontois ┆         ┆ l'Alma  ┆ rceau.
#  ┆         ┆         ┆         ┆         ┆        │
# │ or…     ┆ e,      ┆         ┆         ┆ …       ┆         ┆         ┆         ┆         ┆        │
# │         ┆ Versa…  ┆         ┆         ┆         ┆         ┆         ┆         ┆         ┆        │
# │ https:/ ┆ Champ   ┆ Champ   ┆ Alma -  ┆ La corr ┆ C       ┆ C       ┆ 42182   ┆ C01727  ┆ C01727 │
# │ /www.me ┆ de      ┆ de      ┆ Marceau ┆ esponda ┆         ┆         ┆         ┆         ┆        │
# │ tro-con ┆ Mars,   ┆ Mars,   ┆ Pont de ┆ nce     ┆         ┆         ┆         ┆         ┆        │
# │ nexion. ┆ Pontois ┆ Pontois ┆ l'Alma  ┆ pour    ┆         ┆         ┆         ┆         ┆        │
# │ or…     ┆ e,      ┆ e,      ┆         ┆ retourn ┆         ┆         ┆         ┆         ┆        │
# │         ┆ Versa…  ┆ Versa…  ┆         ┆ …       ┆         ┆         ┆         ┆         ┆        │
# │ https:/ ┆ Champ   ┆ Pont de ┆ Alma -  ┆ Via la  ┆ C       ┆ 9       ┆ 42182   ┆ C01379  ┆ C01727 │
# │ /www.me ┆ de      ┆ Sèvres  ┆ Marceau ┆ station ┆         ┆         ┆         ┆         ┆        │
# │ tro-con ┆ Mars,   ┆         ┆ Pont de ┆ Alma-Ma ┆         ┆         ┆         ┆         ┆        │
# │ nexion. ┆ Pontois ┆         ┆ l'Alma  ┆ rceau.
#  ┆         ┆         ┆         ┆         ┆        │
# │ or…     ┆ e,      ┆         ┆         ┆ …       ┆         ┆         ┆         ┆         ┆        │
# │         ┆ Versa…  ┆         ┆         ┆         ┆         ┆         ┆         ┆         ┆        │
# │ https:/ ┆ Choisy- ┆ Mairie  ┆ Alma -  ┆ Via la  ┆ C       ┆ 9       ┆ 42182   ┆ C01379  ┆ C01727 │
# │ /www.me ┆ le-Roi, ┆ de Mont ┆ Marceau ┆ station ┆         ┆         ┆         ┆         ┆        │
# │ tro-con ┆ Massy-P ┆ reuil   ┆ Pont de ┆ Alma-Ma ┆         ┆         ┆         ┆         ┆        │
# │ nexion. ┆ alaisea ┆         ┆ l'Alma  ┆ rceau.
#  ┆         ┆         ┆         ┆         ┆        │
# │ or…     ┆ u…      ┆         ┆         ┆ …       ┆         ┆         ┆         ┆         ┆        │
# │ https:/ ┆ Choisy- ┆ Choisy- ┆ Alma -  ┆ La corr ┆ C       ┆ C       ┆ 42182   ┆ C01727  ┆ C01727 │
# │ /www.me ┆ le-Roi, ┆ le-Roi, ┆ Marceau ┆ esponda ┆         ┆         ┆         ┆         ┆        │
# │ tro-con ┆ Massy-P ┆ Massy-P ┆ Pont de ┆ nce     ┆         ┆         ┆         ┆         ┆        │
# │ nexion. ┆ alaisea ┆ alaisea ┆ l'Alma  ┆ pour    ┆         ┆         ┆         ┆         ┆        │
# │ or…     ┆ u…      ┆ u…      ┆         ┆ retourn ┆         ┆         ┆         ┆         ┆        │
# │         ┆         ┆         ┆         ┆ …       ┆         ┆         ┆         ┆         ┆        │
# └─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴────────┘

# %%
#Un exemple : il semblerait que les étapes sont séparées par des retours à la ligne
print(repr(df['description_detaillee'][0]))
print(df['description_detaillee'][0])
# Out:
# "Via la station Alma-Marceau.\r\nLa correspondance du RER C Pont de l'Alma vers le métro Alma-Marceau va se faire par l'extérieur en traversant le pont de l'Alma.\r\n\r\nEn tête, passer les composteurs situés contre le mur.\r\nMonter le double escalier. On arrive à l'extérieur en léger contrebas d'un terre-plein qui se trouve face à nous. Pour monter sur le terre-plein, il y a quatre marches en sortant du RER en provenance de Champ de Mars et une seule marche en sortant du RER en provenance de Bibliothèque François Mitterrand. Ce terre-plein est lui-même légèrement en côte en allant vers la Seine. Il forme une sorte de triangle qui se présente comme suit :Devant, les marches permettant de monter sur le terre-plein, (la base du triangle)De 9 H, à 11 H, un autre terre-plein en terre en contrebas que l'on atteint par un court escalier descendant, (le côté gauche du triangle).\r\nEntre 9 H et 3 H, vers le fond, à une quarantaine de mètres, la SeineA 11 H, le pont de l'alma enjambe la SeineDe 11 H, à 5 H, le quai Branly, (le côté droit du triangle)A 1 H, et à 3 H, à quelques mètres, une guérite de renseignements.\r\nEntre 1 H, et 3 H, un étroit passage qui rejoint l'entrée du RER  en direction de Champ de Mars.Faire 7 mètres en prenant garde à une marche descendante à gauche et à un panneau d'information à hauteur de visage.\r\nMonter quatre marches.\r\nContinuer pendant 10 mètres en longeant au début à droite la guérite d'informations.\r\nObliquer légèrement vers la gauche.\r\nContinuer pendant 14 mètres.\r\nObliquer à gauche.\r\nTraverser le pont pendant une centaine de mètres. On arrive sur la place de l'Alma.\r\nL'Avenue de New York est devant nous, à 7 mètres, avec le passage piéton à 11 H. Il va falloir la traverser en deux fois, car elle est séparée par un terre-plein central en haricot.\r\nObliquer vers 11 H, pendant 7 mètres pour trouver le passage piéton.\r\nTraverser la première partie de l'avenue de New york. On arrive sur un terre-plein avec à gauche un petit embranchement qui relie les deux côtés de l'avenue de New York, le monument à la flamme et le souterrain.\r\nObliquer vers 11 H, pour se diriger vers le second passage piéton.\r\nTraverser le terre-plein pendant 18 mètres.\r\nTraverser la seconde partie de l'avenue de New York. On arrive sur un autre terre-plein avec l'avenue du Président Wilson devant nous et l'entrée du métro Alma-Marceau à 1 H, à quelques mètres.\r\nObliquer vers 1 H, pendant quelques mètres.\r\nDescendre l'escalier. On se trouve à présent dans l'enceinte du métro.\r\nTourner à droite.\r\nDescendre l'escalier.\r\nSuivre le couloir pendant 16 mètres. Celui-ci oblique au début vers la gauche. On arrive dans un carrefour qui se présente comme suit :A 10 H, des portes pour les voyageurs qui sortent du métroA 11 H, des composteurs pour entrer dans le métroA 2 H, un couloir pour les sorties.Passer les composteurs à 11 H. On arrive dans un carrefour en éventail qui se présente comme suit :A 7 H, des portes de sortieA 10 H, un escalier descendant pour la direction de Mairie de MontreuilA 2 H, un escalier descendant pour la direction de Pont de Sèvres.Descendre l'escalier à 10 H.\r\nTourner à droite.\r\nDescendre l'escalier.\r\nOn arrive dans le prolongement du quai en tête."
# Via la station Alma-Marceau.
# La correspondance du RER C Pont de l'Alma vers le métro Alma-Marceau va se faire par l'extérieur en traversant le pont de l'Alma.
#
# En tête, passer les composteurs situés contre le mur.
# Monter le double escalier. On arrive à l'extérieur en léger contrebas d'un terre-plein qui se trouve face à nous. Pour monter sur le terre-plein, il y a quatre marches en sortant du RER en provenance de Champ de Mars et une seule marche en sortant du RER en provenance de Bibliothèque François Mitterrand. Ce terre-plein est lui-même légèrement en côte en allant vers la Seine. Il forme une sorte de triangle qui se présente comme suit :Devant, les marches permettant de monter sur le terre-plein, (la base du triangle)De 9 H, à 11 H, un autre terre-plein en terre en contrebas que l'on atteint par un court escalier descendant, (le côté gauche du triangle).
# Entre 9 H et 3 H, vers le fond, à une quarantaine de mètres, la SeineA 11 H, le pont de l'alma enjambe la SeineDe 11 H, à 5 H, le quai Branly, (le côté droit du triangle)A 1 H, et à 3 H, à quelques mètres, une guérite de renseignements.
# Entre 1 H, et 3 H, un étroit passage qui rejoint l'entrée du RER  en direction de Champ de Mars.Faire 7 mètres en prenant garde à une marche descendante à gauche et à un panneau d'information à hauteur de visage.
# Monter quatre marches.
# Continuer pendant 10 mètres en longeant au début à droite la guérite d'informations.
# Obliquer légèrement vers la gauche.
# Continuer pendant 14 mètres.
# Obliquer à gauche.
# Traverser le pont pendant une centaine de mètres. On arrive sur la place de l'Alma.
# L'Avenue de New York est devant nous, à 7 mètres, avec le passage piéton à 11 H. Il va falloir la traverser en deux fois, car elle est séparée par un terre-plein central en haricot.
# Obliquer vers 11 H, pendant 7 mètres pour trouver le passage piéton.
# Traverser la première partie de l'avenue de New york. On arrive sur un terre-plein avec à gauche un petit embranchement qui relie les deux côtés de l'avenue de New York, le monument à la flamme et le souterrain.
# Obliquer vers 11 H, pour se diriger vers le second passage piéton.
# Traverser le terre-plein pendant 18 mètres.
# Traverser la seconde partie de l'avenue de New York. On arrive sur un autre terre-plein avec l'avenue du Président Wilson devant nous et l'entrée du métro Alma-Marceau à 1 H, à quelques mètres.
# Obliquer vers 1 H, pendant quelques mètres.
# Descendre l'escalier. On se trouve à présent dans l'enceinte du métro.
# Tourner à droite.
# Descendre l'escalier.
# Suivre le couloir pendant 16 mètres. Celui-ci oblique au début vers la gauche. On arrive dans un carrefour qui se présente comme suit :A 10 H, des portes pour les voyageurs qui sortent du métroA 11 H, des composteurs pour entrer dans le métroA 2 H, un couloir pour les sorties.Passer les composteurs à 11 H. On arrive dans un carrefour en éventail qui se présente comme suit :A 7 H, des portes de sortieA 10 H, un escalier descendant pour la direction de Mairie de MontreuilA 2 H, un escalier descendant pour la direction de Pont de Sèvres.Descendre l'escalier à 10 H.
# Tourner à droite.
# Descendre l'escalier.
# On arrive dans le prolongement du quai en tête.

# %% [markdown]
# ### quelques exemples de provenance et destinations; il s'agit uniquement des terminus des différentes lignes

# %%
df.select(["provenance", "ligne_de_provenance"]).unique().sort("ligne_de_provenance")
# Out:
# shape: (56, 2)
# ┌─────────────────────────────────┬─────────────────────┐
# │ provenance                      ┆ ligne_de_provenance │
# │ ---                             ┆ ---                 │
# │ str                             ┆ str                 │
# ╞═════════════════════════════════╪═════════════════════╡
# │ La Défense Grande Arche         ┆ 1                   │
# │ Château de Vincennes            ┆ 1                   │
# │ Boulogne                        ┆ 10                  │
# │ Gare d'Austerlitz               ┆ 10                  │
# │ Mairie des Lilas                ┆ 11                  │
# │ Chatelet                        ┆ 11                  │
# │ Mairie d'Issy                   ┆ 12                  │
# │ Mairie d'Aubervilliers          ┆ 12                  │
# │ Saint-Denis - Porte de Paris    ┆ 13                  │
# │ Saint-Denis Université          ┆ 13                  │
# │ Olympiades                      ┆ 14                  │
# │ Mairie de Saint-Ouen            ┆ 14                  │
# │ Nation (2 par Barbès-Rochechou… ┆ 2                   │
# │ Porte Dauphine                  ┆ 2                   │
# │ Galiéni                         ┆ 3                   │
# │ Pont de Levallois               ┆ 3                   │
# │ Gambetta                        ┆ 3B                  │
# │ Porte des Lilas                 ┆ 3B                  │
# │ Porte de Clignancourt           ┆ 4                   │
# │ Bagneux - Lucie Aubrac          ┆ 4                   │
# │ Place d'Italie                  ┆ 5                   │
# │ Bobigny                         ┆ 5                   │
# │ Nation (6 par Denfert-Rocherea… ┆ 6                   │
# │ Charles de Gaulle Etoile        ┆ 6                   │
# │ La Courneuve                    ┆ 7                   │
# │ Mairie d'Ivry - Villejuif       ┆ 7                   │
# │ Pré-Saint-Gervais               ┆ 7B                  │
# │ Louis Blanc                     ┆ 7B                  │
# │ Créteil - Pointe du Lac         ┆ 8                   │
# │ Balard                          ┆ 8                   │
# │ Pont de Sèvres                  ┆ 9                   │
# │ Mairie de Montreuil             ┆ 9                   │
# │ Nanterre-Préfecture, St-Germai… ┆ A                   │
# │ Vincennes, Boissy-St-Léger, Ma… ┆ A                   │
# │ Aulnay-sous-Bois, Aéroport Cha… ┆ B                   │
# │ Bourg-la-Reine, Robinson, St-R… ┆ B                   │
# │ Versailles Rive Gauche, Saint-… ┆ C                   │
# │ Champ de Mars, Pontoise, Versa… ┆ C                   │
# │ Athis-mons Porte de l'Essone    ┆ C                   │
# │ Pontoise                        ┆ C                   │
# │ Choisy-le-Roi, Massy-Palaiseau… ┆ C                   │
# │ Villeneuve-Saint-Georges, Melu… ┆ D                   │
# │ Orry-la-Ville, Creil            ┆ D                   │
# │ Chelles, Villiers-sur-Marne     ┆ E                   │
# │ Haussmann - St-Lazare           ┆ E                   │
# │ Asnières-Genevilliers - Les Co… ┆ T1                  │
# │ Villetaneuse-Université - Épin… ┆ T1                  │
# │ Porte de Versailles, Parce des… ┆ T2                  │
# │ Pont de Bezons                  ┆ T2                  │
# │ Pont du Garigliano              ┆ T3a                 │
# │ Porte de Vincennes              ┆ T3b                 │
# │ Porte D'Asnières - Marguerite … ┆ T3b                 │
# │ Gare de Noisy-le-Sec            ┆ T4                  │
# │ Bondy                           ┆ T4                  │
# │ Châtillon - Montrouge           ┆ T6                  │
# │ Viroflay Rive droite            ┆ T6                  │
# └─────────────────────────────────┴─────────────────────┘

# %%
df.select(["destination", "ligne_de_destination"]).unique().sort("ligne_de_destination")
# Out:
# shape: (54, 2)
# ┌─────────────────────────────────┬──────────────────────┐
# │ destination                     ┆ ligne_de_destination │
# │ ---                             ┆ ---                  │
# │ str                             ┆ str                  │
# ╞═════════════════════════════════╪══════════════════════╡
# │ La Défense Grande Arche         ┆ 1                    │
# │ Château de Vincennes            ┆ 1                    │
# │ Gare d'Austerlitz               ┆ 10                   │
# │ Boulogne                        ┆ 10                   │
# │ Mairie des Lilas                ┆ 11                   │
# │ Chatelet                        ┆ 11                   │
# │ Mairie d'Aubervilliers          ┆ 12                   │
# │ Mairie d'Issy                   ┆ 12                   │
# │ Saint-Denis Université          ┆ 13                   │
# │ Saint-Denis - Porte de Paris    ┆ 13                   │
# │ Mairie de Saint-Ouen            ┆ 14                   │
# │ Olympiades                      ┆ 14                   │
# │ Nation                          ┆ 2                    │
# │ Porte Dauphine                  ┆ 2                    │
# │ Pont de Levallois               ┆ 3                    │
# │ Galiéni                         ┆ 3                    │
# │ Porte des Lilas                 ┆ 3B                   │
# │ Gambetta                        ┆ 3B                   │
# │ Porte de Clignancourt           ┆ 4                    │
# │ Bagneux - Lucie Aubrac          ┆ 4                    │
# │ Bobigny                         ┆ 5                    │
# │ Place d'Italie                  ┆ 5                    │
# │ Charles de Gaulle Etoile        ┆ 6                    │
# │ La Courneuve                    ┆ 7                    │
# │ Mairie d'Ivry - Villejuif       ┆ 7                    │
# │ Pré-Saint-Gervais               ┆ 7B                   │
# │ Louis Blanc                     ┆ 7B                   │
# │ Balard                          ┆ 8                    │
# │ Créteil - Pointe du Lac         ┆ 8                    │
# │ Mairie de Montreuil             ┆ 9                    │
# │ Pont de Sèvres                  ┆ 9                    │
# │ Nanterre-Préfecture, St-Germai… ┆ A                    │
# │ Vincennes, Boissy-St-Léger, Ma… ┆ A                    │
# │ Aulnay-sous-Bois, Aéroport Cha… ┆ B                    │
# │ Bourg-la-Reine, Robinson, St-R… ┆ B                    │
# │ Pontoise                        ┆ C                    │
# │ Versailles Rive Gauche, Saint-… ┆ C                    │
# │ Athis-mons Porte de l'Essone    ┆ C                    │
# │ Champ de Mars, Pontoise, Versa… ┆ C                    │
# │ Choisy-le-Roi, Massy-Palaiseau… ┆ C                    │
# │ Orry-la-Ville, Creil            ┆ D                    │
# │ Villeneuve-Saint-Georges, Melu… ┆ D                    │
# │ Chelles, Villiers-sur-Marne     ┆ E                    │
# │ Haussmann - St-Lazare           ┆ E                    │
# │ Villetaneuse-Université - Épin… ┆ T1                   │
# │ Asnières-Genevilliers - Les Co… ┆ T1                   │
# │ Porte de Versailles, Parce des… ┆ T2                   │
# │ Pont de Bezons                  ┆ T2                   │
# │ Pont du Garigliano              ┆ T3a                  │
# │ Porte de Vincennes              ┆ T3b                  │
# │ Porte D'Asnières - Marguerite … ┆ T3b                  │
# │ Gare de Noisy-le-Sec            ┆ T4                   │
# │ Châtillon - Montrouge           ┆ T6                   │
# │ Viroflay Rive droite            ┆ T6                   │
# └─────────────────────────────────┴──────────────────────┘

# %% [markdown]
# # Create a column with the number of steps in each connecting commute

# %%
df = df.with_columns(
    pl.col("description_detaillee")
      .str.count_matches(r"\r\n")
      .alias("nb_etapes")
)

# %% [markdown]
# # Group by connecting stations

# %%
result = (
    df.group_by("station")
      .agg([
          pl.col("provenance").n_unique().alias("nb_provenance"),
          pl.concat_str(["ligne_de_provenance", "provenance"], separator="-").unique().alias("distinct_provenance"),
          pl.col("destination").n_unique().alias("nb_destination"),
          pl.concat_str(["ligne_de_destination", "destination"], separator="-").unique().alias("distinct_destination"),
          pl.col("nb_etapes").sum().alias("total_nb_etapes")
      ])
)
result.sort('nb_provenance', descending=True)
# Out:
# shape: (127, 6)
# ┌────────────────┬───────────────┬────────────────┬────────────────┬───────────────┬───────────────┐
# │ station        ┆ nb_provenance ┆ distinct_prove ┆ nb_destination ┆ distinct_dest ┆ total_nb_etap │
# │ ---            ┆ ---           ┆ nance          ┆ ---            ┆ ination       ┆ es            │
# │ str            ┆ u32           ┆ ---            ┆ u32            ┆ ---           ┆ ---           │
# │                ┆               ┆ list[str]      ┆                ┆ list[str]     ┆ u32           │
# ╞════════════════╪═══════════════╪════════════════╪════════════════╪═══════════════╪═══════════════╡
# │ Châtelet       ┆ 15            ┆ ["B-Aulnay-sou ┆ 15             ┆ ["4-Porte de  ┆ 9636          │
# │                ┆               ┆ s-Bois,        ┆                ┆ Clignancourt" ┆               │
# │                ┆               ┆ Aéroport…      ┆                ┆ , "1…         ┆               │
# │ Saint-Lazare   ┆ 11            ┆ ["T1-Asnières- ┆ 11             ┆ ["3-Galiéni", ┆ 3990          │
# │                ┆               ┆ Genevilliers - ┆                ┆ "12-Mairie    ┆               │
# │                ┆               ┆ L…             ┆                ┆ d'Aub…        ┆               │
# │ République     ┆ 10            ┆ ["8-Balard",   ┆ 10             ┆ ["3-Galiéni", ┆ 1645          │
# │                ┆               ┆ "5-Bobigny", … ┆                ┆ "5-Bobigny",  ┆               │
# │                ┆               ┆ "9…            ┆                ┆ … "…          ┆               │
# │ Gare de Lyon   ┆ 8             ┆ ["1-Château de ┆ 8              ┆ ["D-Villeneuv ┆ 1364          │
# │                ┆               ┆ Vincennes",    ┆                ┆ e-Saint-Georg ┆               │
# │                ┆               ┆ "1-…           ┆                ┆ es, …         ┆               │
# │ Nation - Place ┆ 8             ┆ ["6-Charles de ┆ 8              ┆ ["1-Château   ┆ 2250          │
# │ des Antilles   ┆               ┆ Gaulle         ┆                ┆ de            ┆               │
# │                ┆               ┆ Etoile",…      ┆                ┆ Vincennes",   ┆               │
# │                ┆               ┆                ┆                ┆ "9-…          ┆               │
# │ Gare du Nord   ┆ 8             ┆ ["B-Aulnay-sou ┆ 12             ┆ ["B-Aulnay-so ┆ 2841          │
# │                ┆               ┆ s-Bois,        ┆                ┆ us-Bois,      ┆               │
# │                ┆               ┆ Aéroport…      ┆                ┆ Aéroport…     ┆               │
# │ Montparnasse - ┆ 8             ┆ ["T1-Asnières- ┆ 8              ┆ ["4-Porte de  ┆ 1317          │
# │ Bienvenüe      ┆               ┆ Genevilliers - ┆                ┆ Clignancourt" ┆               │
# │                ┆               ┆ L…             ┆                ┆ , "1…         ┆               │
# │ Charles de     ┆ 7             ┆ ["1-Château de ┆ 6              ┆ ["A-Vincennes ┆ 988           │
# │ Gaulle -       ┆               ┆ Vincennes",    ┆                ┆ , Boissy-St-L ┆               │
# │ Étoile         ┆               ┆ "1-…           ┆                ┆ éger…         ┆               │
# │ Madeleine      ┆ 6             ┆ ["8-Balard",   ┆ 6              ┆ ["8-Balard",  ┆ 1078          │
# │                ┆               ┆ "8-Créteil -   ┆                ┆ "12-Mairie    ┆               │
# │                ┆               ┆ Poin…          ┆                ┆ d'Issy…       ┆               │
# │ Invalides      ┆ 6             ┆ ["T1-Asnières- ┆ 6              ┆ ["T1-Asnières ┆ 566           │
# │                ┆               ┆ Genevilliers - ┆                ┆ -Genevilliers ┆               │
# │                ┆               ┆ L…             ┆                ┆ - L…          ┆               │
# │ La             ┆ 6             ┆ ["8-Balard",   ┆ 6              ┆ ["10-Gare d'A ┆ 999           │
# │ Motte-Picquet  ┆               ┆ "10-Boulogne", ┆                ┆ usterlitz",   ┆               │
# │ - Grenelle     ┆               ┆ … …            ┆                ┆ "10-B…        ┆               │
# │ Concorde       ┆ 6             ┆ ["8-Balard",   ┆ 6              ┆ ["12-Mairie   ┆ 312           │
# │                ┆               ┆ "1-Château de  ┆                ┆ d'Issy",      ┆               │
# │                ┆               ┆ Vin…           ┆                ┆ "1-La Déf…    ┆               │
# │ Stalingrad     ┆ 6             ┆ ["5-Bobigny",  ┆ 6              ┆ ["7-Mairie    ┆ 1157          │
# │                ┆               ┆ "7-La          ┆                ┆ d'Ivry -      ┆               │
# │                ┆               ┆ Courneuve"…    ┆                ┆ Villejuif"…   ┆               │
# │ Gare de l'Est  ┆ 6             ┆ ["4-Bagneux -  ┆ 6              ┆ ["7-Mairie    ┆ 168           │
# │ Verdun         ┆               ┆ Lucie Aubrac", ┆                ┆ d'Ivry -      ┆               │
# │                ┆               ┆ "…             ┆                ┆ Villejuif"…   ┆               │
# │ Bastille       ┆ 6             ┆ ["8-Balard",   ┆ 6              ┆ ["1-La        ┆ 541           │
# │                ┆               ┆ "5-Bobigny", … ┆                ┆ Défense       ┆               │
# │                ┆               ┆ "5…            ┆                ┆ Grande        ┆               │
# │                ┆               ┆                ┆                ┆ Arche", …     ┆               │
# │ Denfert-Rocher ┆ 6             ┆ ["B-Aulnay-sou ┆ 6              ┆ ["4-Porte de  ┆ 970           │
# │ eau - Colonel  ┆               ┆ s-Bois,        ┆                ┆ Clignancourt" ┆               │
# │ Ro…            ┆               ┆ Aéroport…      ┆                ┆ , "4…         ┆               │
# │ Saint-Denis    ┆ 6             ┆ ["T1-Asnières- ┆ 6              ┆ ["13-Saint-De ┆ 493           │
# │ (gare)         ┆               ┆ Genevilliers - ┆                ┆ nis - Porte   ┆               │
# │                ┆               ┆ L…             ┆                ┆ de Pa…        ┆               │
# │ Strasbourg -   ┆ 6             ┆ ["4-Bagneux -  ┆ 6              ┆ ["4-Bagneux - ┆ 372           │
# │ Saint-Denis    ┆               ┆ Lucie Aubrac", ┆                ┆ Lucie         ┆               │
# │                ┆               ┆ "…             ┆                ┆ Aubrac", "…   ┆               │
# │ Jaurès         ┆ 6             ┆ ["5-Bobigny",  ┆ 6              ┆ ["2-Nation",  ┆ 820           │
# │                ┆               ┆ "7B-Louis      ┆                ┆ "7B-Pré-Saint ┆               │
# │                ┆               ┆ Blanc"…        ┆                ┆ -Ger…         ┆               │
# │ Opéra          ┆ 6             ┆ ["8-Balard",   ┆ 8              ┆ ["A-Vincennes ┆ 2232          │
# │                ┆               ┆ "8-Créteil -   ┆                ┆ , Boissy-St-L ┆               │
# │                ┆               ┆ Poin…          ┆                ┆ éger…         ┆               │
# │ Gare           ┆ 5             ┆ ["5-Bobigny",  ┆ 5              ┆ ["10-Boulogne ┆ 2071          │
# │ d'Austerlitz   ┆               ┆ "10-Boulogne", ┆                ┆ ",            ┆               │
# │                ┆               ┆ ……             ┆                ┆ "5-Bobigny",  ┆               │
# │                ┆               ┆                ┆                ┆ ……            ┆               │
# │ La Défense     ┆ 5             ┆ ["1-Château de ┆ 5              ┆ ["A-Vincennes ┆ 662           │
# │ Grande Arche   ┆               ┆ Vincennes",    ┆                ┆ , Boissy-St-L ┆               │
# │                ┆               ┆ "A-…           ┆                ┆ éger…         ┆               │
# │ Place d'Italie ┆ 5             ┆ ["5-Bobigny",  ┆ 5              ┆ ["7-Mairie    ┆ 508           │
# │                ┆               ┆ "6-Charles de  ┆                ┆ d'Ivry -      ┆               │
# │                ┆               ┆ Ga…            ┆                ┆ Villejuif"…   ┆               │
# │ Porte des      ┆ 5             ┆ ["11-Chatelet" ┆ 5              ┆ ["11-Chatelet ┆ 668           │
# │ Lilas          ┆               ┆ , "3B-Gambetta ┆                ┆ ", "T3b-Porte ┆               │
# │                ┆               ┆ ",…            ┆                ┆ de …          ┆               │
# │ Porte de       ┆ 5             ┆ ["12-Mairie    ┆ 5              ┆ ["T3b-Porte   ┆ 708           │
# │ Versailles -   ┆               ┆ d'Aubervillier ┆                ┆ de            ┆               │
# │ Parc des…      ┆               ┆ s", …          ┆                ┆ Vincennes",   ┆               │
# │                ┆               ┆                ┆                ┆ "T2…          ┆               │
# │ Rosa Parks     ┆ 4             ┆ ["E-Chelles,   ┆ 4              ┆ ["T3b-Porte   ┆ 545           │
# │                ┆               ┆ Villiers-sur-M ┆                ┆ D'Asnières -  ┆               │
# │                ┆               ┆ arn…           ┆                ┆ Margu…        ┆               │
# │ Saint-Michel   ┆ 4             ┆ ["B-Aulnay-sou ┆ 8              ┆ ["B-Aulnay-so ┆ 285           │
# │ Notre Dame     ┆               ┆ s-Bois,        ┆                ┆ us-Bois,      ┆               │
# │                ┆               ┆ Aéroport…      ┆                ┆ Aéroport…     ┆               │
# │ Père Lachaise  ┆ 4             ┆ ["3-Galiéni",  ┆ 4              ┆ ["2-Porte     ┆ 82            │
# │                ┆               ┆ "2-Nation (2   ┆                ┆ Dauphine",    ┆               │
# │                ┆               ┆ par…           ┆                ┆ "3-Galién…    ┆               │
# │ Porte Dorée    ┆ 4             ┆ ["8-Balard",   ┆ 4              ┆ ["T3a-Pont du ┆ 210           │
# │                ┆               ┆ "8-Créteil -   ┆                ┆ Garigliano",  ┆               │
# │                ┆               ┆ Poin…          ┆                ┆ "8-…          ┆               │
# │ Pigalle        ┆ 4             ┆ ["12-Mairie    ┆ 4              ┆ ["2-Nation",  ┆ 117           │
# │                ┆               ┆ d'Aubervillier ┆                ┆ "12-Mairie    ┆               │
# │                ┆               ┆ s", …          ┆                ┆ d'Aube…       ┆               │
# │ Daumesnil -    ┆ 4             ┆ ["8-Balard",   ┆ 4              ┆ ["6-Charles   ┆ 158           │
# │ Félix Éboué    ┆               ┆ "6-Charles de  ┆                ┆ de Gaulle     ┆               │
# │                ┆               ┆ Gau…           ┆                ┆ Etoile",…     ┆               │
# │ Franklin D.    ┆ 4             ┆ ["1-Château de ┆ 4              ┆ ["9-Mairie de ┆ 101           │
# │ Roosevelt      ┆               ┆ Vincennes",    ┆                ┆ Montreuil",   ┆               │
# │                ┆               ┆ "1-…           ┆                ┆ "1-C…         ┆               │
# │ Bonne Nouvelle ┆ 4             ┆ ["8-Balard",   ┆ 4              ┆ ["8-Balard",  ┆ 132           │
# │                ┆               ┆ "8-Créteil -   ┆                ┆ "9-Mairie de  ┆               │
# │                ┆               ┆ Poin…          ┆                ┆ Mont…         ┆               │
# │ Odéon          ┆ 4             ┆ ["4-Bagneux -  ┆ 4              ┆ ["10-Boulogne ┆ 71            │
# │                ┆               ┆ Lucie Aubrac", ┆                ┆ ", "10-Gare   ┆               │
# │                ┆               ┆ "…             ┆                ┆ d'Aus…        ┆               │
# │ Sèvres -       ┆ 4             ┆ ["10-Boulogne" ┆ 4              ┆ ["10-Boulogne ┆ 64            │
# │ Babylone       ┆               ┆ , "10-Gare     ┆                ┆ ", "12-Mairie ┆               │
# │                ┆               ┆ d'Aus…         ┆                ┆ d'A…          ┆               │
# │ Porte de       ┆ 4             ┆ ["T1-Asnières- ┆ 4              ┆ ["C-Choisy-le ┆ 239           │
# │ Clichy         ┆               ┆ Genevilliers - ┆                ┆ -Roi,         ┆               │
# │                ┆               ┆ L…             ┆                ┆ Massy-Palai…  ┆               │
# │ Marcadet -     ┆ 4             ┆ ["4-Bagneux -  ┆ 4              ┆ ["12-Mairie   ┆ 123           │
# │ Poissonniers   ┆               ┆ Lucie Aubrac", ┆                ┆ d'Aubervillie ┆               │
# │                ┆               ┆ "…             ┆                ┆ rs", …        ┆               │
# │ Pyramides      ┆ 4             ┆ ["7-La         ┆ 4              ┆ ["14-Olympiad ┆ 398           │
# │                ┆               ┆ Courneuve",    ┆                ┆ es",          ┆               │
# │                ┆               ┆ "7-Mairie d…   ┆                ┆ "14-Mairie d… ┆               │
# │ Villiers       ┆ 4             ┆ ["3-Galiéni",  ┆ 4              ┆ ["2-Nation",  ┆ 58            │
# │                ┆               ┆ "2-Nation (2   ┆                ┆ "3-Galiéni",  ┆               │
# │                ┆               ┆ par…           ┆                ┆ … "3…         ┆               │
# │ La Courneuve - ┆ 4             ┆ ["T1-Asnières- ┆ 3              ┆ ["7-Mairie    ┆ 224           │
# │ 8 Mai          ┆               ┆ Genevilliers - ┆                ┆ d'Ivry -      ┆               │
# │                ┆               ┆ L…             ┆                ┆ Villejuif"…   ┆               │
# │ Bibliothèque   ┆ 4             ┆ ["C-Champ de   ┆ 6              ┆ ["T3a-Pont du ┆ 1526          │
# │ François       ┆               ┆ Mars,          ┆                ┆ Garigliano",  ┆               │
# │ Mitterra…      ┆               ┆ Pontoise, V…   ┆                ┆ "T3…          ┆               │
# │ Place de       ┆ 4             ┆ ["T1-Asnières- ┆ 4              ┆ ["2-Porte     ┆ 140           │
# │ Clichy         ┆               ┆ Genevilliers - ┆                ┆ Dauphine",    ┆               │
# │                ┆               ┆ L…             ┆                ┆ "2-Nation…    ┆               │
# │ Porte de       ┆ 4             ┆ ["9-Mairie de  ┆ 4              ┆ ["T3b-Porte   ┆ 251           │
# │ Montreuil      ┆               ┆ Montreuil",    ┆                ┆ de            ┆               │
# │                ┆               ┆ "9-P…          ┆                ┆ Vincennes",   ┆               │
# │                ┆               ┆                ┆                ┆ "T3…          ┆               │
# │ Oberkampf      ┆ 4             ┆ ["5-Bobigny",  ┆ 4              ┆ ["9-Pont de   ┆ 79            │
# │                ┆               ┆ "9-Mairie de   ┆                ┆ Sèvres",      ┆               │
# │                ┆               ┆ Mon…           ┆                ┆ "9-Mairie…    ┆               │
# │ Reuilly -      ┆ 4             ┆ ["8-Balard",   ┆ 4              ┆ ["1-La        ┆ 88            │
# │ Diderot        ┆               ┆ "1-Château de  ┆                ┆ Défense       ┆               │
# │                ┆               ┆ Vin…           ┆                ┆ Grande        ┆               │
# │                ┆               ┆                ┆                ┆ Arche", …     ┆               │
# │ Porte de la    ┆ 4             ┆ ["12-Mairie    ┆ 4              ┆ ["T3b-Porte   ┆ 166           │
# │ Chapelle       ┆               ┆ d'Aubervillier ┆                ┆ de            ┆               │
# │                ┆               ┆ s", …          ┆                ┆ Vincennes",   ┆               │
# │                ┆               ┆                ┆                ┆ "T3…          ┆               │
# │ Porte          ┆ 4             ┆ ["4-Bagneux -  ┆ 4              ┆ ["4-Bagneux - ┆ 311           │
# │ d'Orléans      ┆               ┆ Lucie Aubrac", ┆                ┆ Lucie         ┆               │
# │ Général        ┆               ┆ "…             ┆                ┆ Aubrac", "…   ┆               │
# │ Lecler…        ┆               ┆                ┆                ┆               ┆               │
# │ Arts et        ┆ 4             ┆ ["11-Chatelet" ┆ 4              ┆ ["3-Pont de   ┆ 122           │
# │ Métiers        ┆               ┆ , "3-Galiéni", ┆                ┆ Levallois",   ┆               │
# │                ┆               ┆ ……             ┆                ┆ "3-Gal…       ┆               │
# │ Gare de        ┆ 4             ┆ ["T1-Asnières- ┆ 4              ┆ ["T1-Asnières ┆ 214           │
# │ Genevilliers   ┆               ┆ Genevilliers - ┆                ┆ -Genevilliers ┆               │
# │                ┆               ┆ L…             ┆                ┆ - L…          ┆               │
# │ Basilique de   ┆ 4             ┆ ["T1-Asnières- ┆ 4              ┆ ["13-Saint-De ┆ 237           │
# │ Saint-Denis    ┆               ┆ Genevilliers - ┆                ┆ nis           ┆               │
# │                ┆               ┆ L…             ┆                ┆ Université",  ┆               │
# │                ┆               ┆                ┆                ┆ …             ┆               │
# │ Grands         ┆ 4             ┆ ["8-Balard",   ┆ 4              ┆ ["9-Pont de   ┆ 393           │
# │ Boulevards     ┆               ┆ "8-Créteil -   ┆                ┆ Sèvres",      ┆               │
# │                ┆               ┆ Poin…          ┆                ┆ "9-Mairie…    ┆               │
# │ Bercy          ┆ 4             ┆ ["6-Charles de ┆ 4              ┆ ["6-Charles   ┆ 373           │
# │                ┆               ┆ Gaulle         ┆                ┆ de Gaulle     ┆               │
# │                ┆               ┆ Etoile",…      ┆                ┆ Etoile",…     ┆               │
# │ Porte de       ┆ 4             ┆ ["7-La         ┆ 4              ┆ ["7-La        ┆ 151           │
# │ Choisy         ┆               ┆ Courneuve",    ┆                ┆ Courneuve",   ┆               │
# │                ┆               ┆ "7-Mairie d…   ┆                ┆ "T3a-Pont d…  ┆               │
# │ Porte de       ┆ 4             ┆ ["5-Bobigny",  ┆ 4              ┆ ["5-Bobigny", ┆ 299           │
# │ Pantin - Parc  ┆               ┆ "5-Place       ┆                ┆ "T3b-Porte de ┆               │
# │ de la V…       ┆               ┆ d'Itali…       ┆                ┆ Vi…           ┆               │
# │ Trocadéro      ┆ 4             ┆ ["6-Charles de ┆ 4              ┆ ["9-Mairie de ┆ 93            │
# │                ┆               ┆ Gaulle         ┆                ┆ Montreuil",   ┆               │
# │                ┆               ┆ Etoile",…      ┆                ┆ "6-C…         ┆               │
# │ Porte de       ┆ 4             ┆ ["1-Château de ┆ 4              ┆ ["T3a-Pont du ┆ 241           │
# │ Vincennes      ┆               ┆ Vincennes",    ┆                ┆ Garigliano",  ┆               │
# │                ┆               ┆ "1-…           ┆                ┆ "T3…          ┆               │
# │ Porte de       ┆ 4             ┆ ["T1-Asnières- ┆ 4              ┆ ["T3a-Pont du ┆ 210           │
# │ Vanves         ┆               ┆ Genevilliers - ┆                ┆ Garigliano",  ┆               │
# │                ┆               ┆ L…             ┆                ┆ "T1…          ┆               │
# │ Porte d'Ivry   ┆ 4             ┆ ["7-La         ┆ 4              ┆ ["7-La        ┆ 281           │
# │                ┆               ┆ Courneuve",    ┆                ┆ Courneuve",   ┆               │
# │                ┆               ┆ "7-Mairie d…   ┆                ┆ "T3a-Pont d…  ┆               │
# │ Barbès -       ┆ 4             ┆ ["4-Bagneux -  ┆ 4              ┆ ["4-Bagneux - ┆ 581           │
# │ Rochechouart   ┆               ┆ Lucie Aubrac", ┆                ┆ Lucie         ┆               │
# │                ┆               ┆ "…             ┆                ┆ Aubrac", "…   ┆               │
# │ Belleville     ┆ 4             ┆ ["11-Chatelet" ┆ 4              ┆ ["11-Chatelet ┆ 129           │
# │                ┆               ┆ , "11-Mairie   ┆                ┆ ",            ┆               │
# │                ┆               ┆ des…           ┆                ┆ "2-Nation", … ┆               │
# │                ┆               ┆                ┆                ┆ …             ┆               │
# │ Duroc          ┆ 4             ┆ ["T1-Asnières- ┆ 4              ┆ ["10-Gare d'A ┆ 167           │
# │                ┆               ┆ Genevilliers - ┆                ┆ usterlitz",   ┆               │
# │                ┆               ┆ L…             ┆                ┆ "T1-A…        ┆               │
# │ Alma - Marceau ┆ 4             ┆ ["C-Champ de   ┆ 4              ┆ ["9-Mairie de ┆ 259           │
# │ Pont de l'Alma ┆               ┆ Mars,          ┆                ┆ Montreuil",   ┆               │
# │                ┆               ┆ Pontoise, V…   ┆                ┆ "C-C…         ┆               │
# │ Cité           ┆ 4             ┆ ["B-Aulnay-sou ┆ 4              ┆ ["T3a-Pont du ┆ 435           │
# │ Universitaire  ┆               ┆ s-Bois,        ┆                ┆ Garigliano",  ┆               │
# │                ┆               ┆ Aéroport…      ┆                ┆ "T3…          ┆               │
# │ Issy-Val-de-Se ┆ 4             ┆ ["C-Champ de   ┆ 4              ┆ ["T2-Porte de ┆ 504           │
# │ ine            ┆               ┆ Mars,          ┆                ┆ Versailles,   ┆               │
# │                ┆               ┆ Pontoise, V…   ┆                ┆ Parc…         ┆               │
# │ Havre -        ┆ 4             ┆ ["3-Galiéni",  ┆ 7              ┆ ["A-Nanterre- ┆ 878           │
# │ Caumartin      ┆               ┆ "9-Mairie de   ┆                ┆ Préfecture,   ┆               │
# │                ┆               ┆ Mon…           ┆                ┆ St-Ge…        ┆               │
# │ Miromesnil     ┆ 4             ┆ ["T1-Asnières- ┆ 4              ┆ ["9-Pont de   ┆ 161           │
# │                ┆               ┆ Genevilliers - ┆                ┆ Sèvres",      ┆               │
# │                ┆               ┆ L…             ┆                ┆ "9-Mairie…    ┆               │
# │ Pasteur        ┆ 4             ┆ ["6-Charles de ┆ 4              ┆ ["12-Mairie   ┆ 116           │
# │                ┆               ┆ Gaulle         ┆                ┆ d'Issy",      ┆               │
# │                ┆               ┆ Etoile",…      ┆                ┆ "6-Charle…    ┆               │
# │ Richelieu -    ┆ 4             ┆ ["8-Balard",   ┆ 4              ┆ ["9-Pont de   ┆ 127           │
# │ Drouot         ┆               ┆ "8-Créteil -   ┆                ┆ Sèvres",      ┆               │
# │                ┆               ┆ Poin…          ┆                ┆ "8-Balard…    ┆               │
# │ Porte de la    ┆ 4             ┆ ["7-La         ┆ 4              ┆ ["7-La        ┆ 228           │
# │ Villette       ┆               ┆ Courneuve",    ┆                ┆ Courneuve",   ┆               │
# │                ┆               ┆ "7-Mairie d…   ┆                ┆ "T3b-Porte …  ┆               │
# │ Porte de       ┆ 4             ┆ ["3-Galiéni",  ┆ 4              ┆ ["3-Galiéni", ┆ 148           │
# │ Bagnolet       ┆               ┆ "3-Pont de     ┆                ┆ "T3b-Porte de ┆               │
# │                ┆               ┆ Leval…         ┆                ┆ Vi…           ┆               │
# │ Palais Royal - ┆ 4             ┆ ["1-Château de ┆ 4              ┆ ["7-Mairie    ┆ 223           │
# │ Musée du       ┆               ┆ Vincennes",    ┆                ┆ d'Ivry -      ┆               │
# │ Louvre         ┆               ┆ "7-…           ┆                ┆ Villejuif"…   ┆               │
# │ Champs-Élysées ┆ 4             ┆ ["T1-Asnières- ┆ 4              ┆ ["T1-Asnières ┆ 152           │
# │ - Clemenceau - ┆               ┆ Genevilliers - ┆                ┆ -Genevilliers ┆               │
# │ …              ┆               ┆ L…             ┆                ┆ - L…          ┆               │
# │ Porte d'Italie ┆ 4             ┆ ["7-La         ┆ 4              ┆ ["7-La        ┆ 275           │
# │                ┆               ┆ Courneuve",    ┆                ┆ Courneuve",   ┆               │
# │                ┆               ┆ "7-Mairie d…   ┆                ┆ "T3a-Pont d…  ┆               │
# │ Réaumur -      ┆ 4             ┆ ["4-Bagneux -  ┆ 4              ┆ ["4-Bagneux - ┆ 145           │
# │ Sébastopol     ┆               ┆ Lucie Aubrac", ┆                ┆ Lucie         ┆               │
# │                ┆               ┆ "…             ┆                ┆ Aubrac", "…   ┆               │
# │ Hôtel de Ville ┆ 4             ┆ ["1-Château de ┆ 4              ┆ ["11-Chatelet ┆ 146           │
# │                ┆               ┆ Vincennes",    ┆                ┆ ", "11-Mairie ┆               │
# │                ┆               ┆ "11…           ┆                ┆ des…          ┆               │
# │ Porte de       ┆ 4             ┆ ["8-Balard",   ┆ 4              ┆ ["T3a-Pont du ┆ 185           │
# │ Charenton      ┆               ┆ "8-Créteil -   ┆                ┆ Garigliano",  ┆               │
# │                ┆               ┆ Poin…          ┆                ┆ "8-…          ┆               │
# │ Jussieu        ┆ 4             ┆ ["10-Boulogne" ┆ 4              ┆ ["10-Boulogne ┆ 179           │
# │                ┆               ┆ , "10-Gare     ┆                ┆ ", "7-Mairie  ┆               │
# │                ┆               ┆ d'Aus…         ┆                ┆ d'Iv…         ┆               │
# │ Raspail        ┆ 4             ┆ ["4-Bagneux -  ┆ 4              ┆ ["4-Bagneux - ┆ 123           │
# │                ┆               ┆ Lucie Aubrac", ┆                ┆ Lucie         ┆               │
# │                ┆               ┆ "…             ┆                ┆ Aubrac", "…   ┆               │
# │ Chaussée       ┆ 4             ┆ ["7-La         ┆ 4              ┆ ["9-Mairie de ┆ 238           │
# │ d'Antin - La   ┆               ┆ Courneuve",    ┆                ┆ Montreuil",   ┆               │
# │ Fayette        ┆               ┆ "7-Mairie d…   ┆                ┆ "7-L…         ┆               │
# │ Louis Blanc    ┆ 3             ┆ ["7-La         ┆ 3              ┆ ["7B-Pré-Sain ┆ 58            │
# │                ┆               ┆ Courneuve",    ┆                ┆ t-Gervais",   ┆               │
# │                ┆               ┆ "7-Mairie d…   ┆                ┆ "7-La…        ┆               │
# │ Hôpital Robert ┆ 3             ┆ ["7B-Louis     ┆ 3              ┆ ["T3b-Porte   ┆ 227           │
# │ Debré          ┆               ┆ Blanc",        ┆                ┆ de            ┆               │
# │                ┆               ┆ "T3b-Porte …   ┆                ┆ Vincennes",   ┆               │
# │                ┆               ┆                ┆                ┆ "T3…          ┆               │
# │ Magenta        ┆ 3             ┆ ["E-Chelles,   ┆ 12             ┆ ["B-Aulnay-so ┆ 1209          │
# │                ┆               ┆ Villiers-sur-M ┆                ┆ us-Bois,      ┆               │
# │                ┆               ┆ arn…           ┆                ┆ Aéroport…     ┆               │
# │ Noisy le Sec   ┆ 3             ┆ ["T1-Asnières- ┆ 3              ┆ ["T1-Asnières ┆ 382           │
# │ (gare)         ┆               ┆ Genevilliers - ┆                ┆ -Genevilliers ┆               │
# │                ┆               ┆ L…             ┆                ┆ - L…          ┆               │
# │ Balard         ┆ 3             ┆ ["8-Créteil -  ┆ 5              ┆ ["T2-Porte de ┆ 345           │
# │                ┆               ┆ Pointe du      ┆                ┆ Versailles,   ┆               │
# │                ┆               ┆ Lac", …        ┆                ┆ Parc…         ┆               │
# │ Michel-Ange -  ┆ 3             ┆ ["10-Boulogne" ┆ 3              ┆ ["9-Pont de   ┆ 27            │
# │ Molitor        ┆               ┆ , "9-Mairie de ┆                ┆ Sèvres",      ┆               │
# │                ┆               ┆ M…             ┆                ┆ "9-Mairie…    ┆               │
# │ Michel-Ange -  ┆ 3             ┆ ["10-Gare      ┆ 3              ┆ ["9-Pont de   ┆ 29            │
# │ Auteuil        ┆               ┆ d'Austerlitz", ┆                ┆ Sèvres",      ┆               │
# │                ┆               ┆ "9-Ma…         ┆                ┆ "9-Mairie…    ┆               │
# │ Gambetta       ┆ 3             ┆ ["3-Galiéni",  ┆ 3              ┆ ["3-Galiéni", ┆ 63            │
# │                ┆               ┆ "3-Pont de     ┆                ┆ "3B-Porte des ┆               │
# │                ┆               ┆ Leval…         ┆                ┆ Li…           ┆               │
# │ Saint-Denis -  ┆ 3             ┆ ["T6-Châtillon ┆ 5              ┆ ["T1-Villetan ┆ 363           │
# │ Porte de Paris ┆               ┆ - Montrouge",  ┆                ┆ euse-Universi ┆               │
# │ -…             ┆               ┆ "…             ┆                ┆ té -…         ┆               │
# │ Place des      ┆ 3             ┆ ["11-Chatelet" ┆ 3              ┆ ["7B-Louis    ┆ 56            │
# │ Fêtes          ┆               ┆ , "7B-Louis    ┆                ┆ Blanc",       ┆               │
# │                ┆               ┆ Blan…          ┆                ┆ "11-Chatele…  ┆               │
# │ Bobigny -      ┆ 3             ┆ ["T1-Asnières- ┆ 3              ┆ ["5-Place     ┆ 260           │
# │ Pablo Picasso  ┆               ┆ Genevilliers - ┆                ┆ d'Italie",    ┆               │
# │ Préfec…        ┆               ┆ L…             ┆                ┆ "T1-Asniè…    ┆               │
# │ Avenue Foch    ┆ 2             ┆ ["C-Choisy-le- ┆ 3              ┆ ["C-Choisy-le ┆ 56            │
# │                ┆               ┆ Roi,           ┆                ┆ -Roi,         ┆               │
# │                ┆               ┆ Massy-Palai…   ┆                ┆ Massy-Palai…  ┆               │
# │ Châtillon -    ┆ 2             ┆ ["T1-Asnières- ┆ 2              ┆ ["T6-Viroflay ┆ 57            │
# │ Montrouge      ┆               ┆ Genevilliers - ┆                ┆ Rive droite", ┆               │
# │                ┆               ┆ L…             ┆                ┆ "T…           ┆               │
# │ Avenue de      ┆ 2             ┆ ["T3a-Pont du  ┆ 6              ┆ ["14-Mairie   ┆ 379           │
# │ France         ┆               ┆ Garigliano",   ┆                ┆ de            ┆               │
# │                ┆               ┆ "T3…           ┆                ┆ Saint-Ouen",  ┆               │
# │                ┆               ┆                ┆                ┆ "C…           ┆               │
# │ Bir-Hakeim     ┆ 2             ┆ ["6-Charles de ┆ 4              ┆ ["6-Charles   ┆ 316           │
# │ Grenelle       ┆               ┆ Gaulle         ┆                ┆ de Gaulle     ┆               │
# │                ┆               ┆ Etoile",…      ┆                ┆ Etoile",…     ┆               │
# │ Ledru-Rollin   ┆ 2             ┆ ["8-Balard",   ┆ 2              ┆ ["8-Balard",  ┆ 21            │
# │                ┆               ┆ "8-Créteil -   ┆                ┆ "8-Créteil -  ┆               │
# │                ┆               ┆ Poin…          ┆                ┆ Poin…         ┆               │
# │ Pantin         ┆ 2             ┆ ["E-Chelles,   ┆ 4              ┆ ["E-Chelles,  ┆ 96            │
# │                ┆               ┆ Villiers-sur-M ┆                ┆ Villiers-sur- ┆               │
# │                ┆               ┆ arn…           ┆                ┆ Marn…         ┆               │
# │ Musée de       ┆ 2             ┆ ["T2-Pont de   ┆ 3              ┆ ["9-Mairie de ┆ 212           │
# │ Sèvres         ┆               ┆ Bezons",       ┆                ┆ Montreuil",   ┆               │
# │                ┆               ┆ "T2-Port…      ┆                ┆ "T2-…         ┆               │
# │ Saint-Augustin ┆ 2             ┆ ["9-Mairie de  ┆ 9              ┆ ["3-Galiéni", ┆ 201           │
# │                ┆               ┆ Montreuil",    ┆                ┆ "3-Pont de    ┆               │
# │                ┆               ┆ "9-P…          ┆                ┆ Leval…        ┆               │
# │ Péreire-Levall ┆ 2             ┆ ["C-Choisy-le- ┆ 4              ┆ ["C-Choisy-le ┆ 109           │
# │ ois            ┆               ┆ Roi,           ┆                ┆ -Roi,         ┆               │
# │                ┆               ┆ Massy-Palai…   ┆                ┆ Massy-Palai…  ┆               │
# │ Champs de Mars ┆ 2             ┆ ["C-Champ de   ┆ 4              ┆ ["2-Nation",  ┆ 209           │
# │ - Tour Eiffel  ┆               ┆ Mars,          ┆                ┆ "6-Charles de ┆               │
# │                ┆               ┆ Pontoise, V…   ┆                ┆ Gau…          ┆               │
# │ Porte Maillot  ┆ 2             ┆ ["1-Château de ┆ 4              ┆ ["1-Château   ┆ 109           │
# │ Palais des     ┆               ┆ Vincennes",    ┆                ┆ de            ┆               │
# │ Congr…         ┆               ┆ "1-…           ┆                ┆ Vincennes",   ┆               │
# │                ┆               ┆                ┆                ┆ "C-…          ┆               │
# │ Javel          ┆ 2             ┆ ["C-Choisy-le- ┆ 4              ┆ ["10-Gare d'A ┆ 92            │
# │                ┆               ┆ Roi,           ┆                ┆ usterlitz",   ┆               │
# │                ┆               ┆ Massy-Palai…   ┆                ┆ "10-B…        ┆               │
# │ Pont du        ┆ 2             ┆ ["T3a-Pont du  ┆ 4              ┆ ["C-Champ de  ┆ 44            │
# │ Garigliano     ┆               ┆ Garigliano",   ┆                ┆ Mars,         ┆               │
# │ Hôpital Eur…   ┆               ┆ "T3…           ┆                ┆ Pontoise, V…  ┆               │
# │ Musée d'Orsay  ┆ 2             ┆ ["C-Champ de   ┆ 4              ┆ ["12-Mairie   ┆ 213           │
# │                ┆               ┆ Mars,          ┆                ┆ d'Issy",      ┆               │
# │                ┆               ┆ Pontoise, V…   ┆                ┆ "C-Champ …    ┆               │
# │ Boulainvillier ┆ 2             ┆ ["C-Choisy-le- ┆ 4              ┆ ["9-Mairie de ┆ 49            │
# │ s              ┆               ┆ Roi,           ┆                ┆ Montreuil",   ┆               │
# │                ┆               ┆ Massy-Palai…   ┆                ┆ "C-C…         ┆               │
# │ Solférino      ┆ 2             ┆ ["12-Mairie    ┆ 4              ┆ ["12-Mairie   ┆ 179           │
# │                ┆               ┆ d'Aubervillier ┆                ┆ d'Aubervillie ┆               │
# │                ┆               ┆ s", …          ┆                ┆ rs", …        ┆               │
# │ Cluny - La     ┆ 2             ┆ ["10-Boulogne" ┆ 6              ┆ ["C-Choisy-le ┆ 202           │
# │ Sorbonne       ┆               ┆ , "10-Gare     ┆                ┆ -Roi,         ┆               │
# │                ┆               ┆ d'Aus…         ┆                ┆ Massy-Palai…  ┆               │
# │ Charonne       ┆ 2             ┆ ["9-Mairie de  ┆ 2              ┆ ["9-Mairie de ┆ 16            │
# │                ┆               ┆ Montreuil",    ┆                ┆ Montreuil",   ┆               │
# │                ┆               ┆ "9-P…          ┆                ┆ "9-P…         ┆               │
# │ Villejuif -    ┆ 2             ┆ ["C-Athis-mons ┆ 2              ┆ ["7-La        ┆ 265           │
# │ Louis Aragon   ┆               ┆ Porte de       ┆                ┆ Courneuve",   ┆               │
# │                ┆               ┆ l'Esso…        ┆                ┆ "C-Athis-mo…  ┆               │
# │ Suzanne        ┆ 2             ┆ ["T2-Pont de   ┆ 5              ┆ ["T3a-Pont du ┆ 203           │
# │ Lenglen        ┆               ┆ Bezons",       ┆                ┆ Garigliano",  ┆               │
# │                ┆               ┆ "T2-Port…      ┆                ┆ "8-…          ┆               │
# │ La Chapelle    ┆ 2             ┆ ["2-Nation (2  ┆ 12             ┆ ["B-Aulnay-so ┆ 846           │
# │                ┆               ┆ par            ┆                ┆ us-Bois,      ┆               │
# │                ┆               ┆ Barbès-Roche…  ┆                ┆ Aéroport…     ┆               │
# │ Les Halles     ┆ 2             ┆ ["4-Bagneux -  ┆ 8              ┆ ["B-Bourg-la- ┆ 137           │
# │                ┆               ┆ Lucie Aubrac", ┆                ┆ Reine,        ┆               │
# │                ┆               ┆ "…             ┆                ┆ Robinson, …   ┆               │
# │ Neuilly -      ┆ 2             ┆ ["C-Choisy-le- ┆ 4              ┆ ["1-La        ┆ 112           │
# │ Porte Maillot  ┆               ┆ Roi,           ┆                ┆ Défense       ┆               │
# │                ┆               ┆ Massy-Palai…   ┆                ┆ Grande        ┆               │
# │                ┆               ┆                ┆                ┆ Arche", …     ┆               │
# │ Saint-Michel   ┆ 2             ┆ ["4-Bagneux -  ┆ 6              ┆ ["C-Choisy-le ┆ 195           │
# │                ┆               ┆ Lucie Aubrac", ┆                ┆ -Roi,         ┆               │
# │                ┆               ┆ "…             ┆                ┆ Massy-Palai…  ┆               │
# │ Asnières -     ┆ 2             ┆ ["T6-Châtillon ┆ 2              ┆ ["T4-Gare de  ┆ 173           │
# │ Gennevilliers  ┆               ┆ - Montrouge",  ┆                ┆ Noisy-le-Sec" ┆               │
# │ - Les…         ┆               ┆ "…             ┆                ┆ , "T…         ┆               │
# │ Ella           ┆ 2             ┆ ["T3b-Porte    ┆ 4              ┆ ["E-Haussmann ┆ 96            │
# │ Fitzgerald     ┆               ┆ D'Asnières -   ┆                ┆ - St-Lazare", ┆               │
# │                ┆               ┆ Margu…         ┆                ┆ "E…           ┆               │
# │ Boulevard      ┆ 2             ┆ ["C-Champ de   ┆ 3              ┆ ["T3b-Porte   ┆ 40            │
# │ Victor - Pont  ┆               ┆ Mars,          ┆                ┆ de            ┆               │
# │ du Gar…        ┆               ┆ Pontoise, V…   ┆                ┆ Vincennes",   ┆               │
# │                ┆               ┆                ┆                ┆ "C-…          ┆               │
# │ Parc de        ┆ 2             ┆ ["T2-Pont de   ┆ 3              ┆ ["10-Gare d'A ┆ 93            │
# │ Saint-Cloud    ┆               ┆ Bezons",       ┆                ┆ usterlitz",   ┆               │
# │                ┆               ┆ "T2-Port…      ┆                ┆ "T2-P…        ┆               │
# │ Javel - André  ┆ 2             ┆ ["10-Boulogne" ┆ 4              ┆ ["C-Choisy-le ┆ 108           │
# │ Citroën        ┆               ┆ , "10-Gare     ┆                ┆ -Roi,         ┆               │
# │                ┆               ┆ d'Aus…         ┆                ┆ Massy-Palai…  ┆               │
# │ La Muette      ┆ 2             ┆ ["9-Mairie de  ┆ 4              ┆ ["C-Champ de  ┆ 45            │
# │                ┆               ┆ Montreuil",    ┆                ┆ Mars,         ┆               │
# │                ┆               ┆ "9-P…          ┆                ┆ Pontoise, V…  ┆               │
# │ Péreire        ┆ 2             ┆ ["3-Galiéni",  ┆ 4              ┆ ["C-Choisy-le ┆ 81            │
# │ Maréchal Juin  ┆               ┆ "3-Pont de     ┆                ┆ -Roi,         ┆               │
# │                ┆               ┆ Leval…         ┆                ┆ Massy-Palai…  ┆               │
# │ Auber          ┆ 2             ┆ ["A-Nanterre-P ┆ 11             ┆ ["7-Mairie    ┆ 1484          │
# │                ┆               ┆ réfecture,     ┆                ┆ d'Ivry -      ┆               │
# │                ┆               ┆ St-Ge…         ┆                ┆ Villejuif"…   ┆               │
# │ Haussemann     ┆ 1             ┆ ["E-Chelles,   ┆ 12             ┆ ["T1-Asnières ┆ 2461          │
# │                ┆               ┆ Villiers-sur-M ┆                ┆ -Genevilliers ┆               │
# │                ┆               ┆ arn…           ┆                ┆ - L…          ┆               │
# │ Porte Dauphine ┆ 1             ┆ ["2-Nation (2  ┆ 3              ┆ ["C-Choisy-le ┆ 69            │
# │ - Maréchal de  ┆               ┆ par            ┆                ┆ -Roi,         ┆               │
# │ L…             ┆               ┆ Barbès-Roche…  ┆                ┆ Massy-Palai…  ┆               │
# │ Boulogne -     ┆ 1             ┆ ["10-Boulogne" ┆ 2              ┆ ["T2-Porte de ┆ 59            │
# │ Pont de        ┆               ┆ ]              ┆                ┆ Versailles,   ┆               │
# │ Saint-Cloud    ┆               ┆                ┆                ┆ Parc…         ┆               │
# │ Pont de Sèvres ┆ 1             ┆ ["9-Mairie de  ┆ 3              ┆ ["T2-Porte de ┆ 119           │
# │                ┆               ┆ Montreuil"]    ┆                ┆ Versailles,   ┆               │
# │                ┆               ┆                ┆                ┆ Parc…         ┆               │
# │ Pré            ┆ 1             ┆ ["7B-Louis     ┆ 3              ┆ ["T3b-Porte   ┆ 110           │
# │ Saint-Gervais  ┆               ┆ Blanc"]        ┆                ┆ de            ┆               │
# │                ┆               ┆                ┆                ┆ Vincennes",   ┆               │
# │                ┆               ┆                ┆                ┆ "T3…          ┆               │
# └────────────────┴───────────────┴────────────────┴────────────────┴───────────────┴───────────────┘
