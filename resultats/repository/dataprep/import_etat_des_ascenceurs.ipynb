# %%
import polars as pl
import geopandas as gpd
from utils.loader_local import LoaderLocal

# %%
# Read data
def read_etat_des_ascenceurs():
    df = pl.read_csv('/home/onyxia/work/hackathon_mobilites_2025/data/raw/etat-des-ascenseurs.csv', 
    separator=";",
    truncate_ragged_lines=True)
    return df

# %%
df_ascensceurs = read_etat_des_ascenceurs()
print('df_ascensceurs number of rows : %i' %df_ascensceurs.shape[0])

df_asc_counts = (
    df_ascensceurs
        .group_by("zdcid")
        .agg(
            pl.col("liftid").n_unique().alias("n_lifts")
        )
)
print('df_ascensceurs_count_by_stations number of rows : %i' %df_asc_counts.shape[0])
# Out:
# df_ascensceurs number of rows : 944
# df_ascensceurs_count_by_stations number of rows : 313

# %%
ref_table_finale_path = "/home/onyxia/work/hackathon_mobilites_2025/data/enrich/final_table.gpq"

stations = LoaderLocal.loader_geoparquet(ref_table_finale_path)
print('stations number of rows : %i' %stations.shape[0])
# Out:
# stations number of rows : 590

# %%
#Attention : format particulier de l'id dans stations
stations_pl.filter(pl.col('id_ref_zdc')=='71485.0')
# Out:
# shape: (1, 16)
# ┌────────────┬───────────┬───────────┬───────────┬───┬─────────┬───────────┬───────────┬───────────┐
# │ geo_point_ ┆ id_ref_zd ┆ nom_zda   ┆ station_c ┆ … ┆ id_zdc  ┆ total_val ┆ total_val ┆ pct_ameth │
# │ 2d         ┆ c         ┆ ---       ┆ lean      ┆   ┆ ---     ┆ idation   ┆ idation_a ┆ yste      │
# │ ---        ┆ ---       ┆ str       ┆ ---       ┆   ┆ str     ┆ ---       ┆ methyste  ┆ ---       │
# │ str        ┆ str       ┆           ┆ str       ┆   ┆         ┆ f64       ┆ ---       ┆ f64       │
# │            ┆           ┆           ┆           ┆   ┆         ┆           ┆ f64       ┆           │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═════════╪═══════════╪═══════════╪═══════════╡
# │ 48.8881384 ┆ 71485.0   ┆ Esplanade ┆ esplanade ┆ … ┆ 71485.0 ┆ 1.3710823 ┆ 1.958689e ┆ 14.2857   │
# │ 7761218,   ┆           ┆ de La     ┆ deladéfen ┆   ┆         ┆ e8        ┆ 7         ┆           │
# │ 2.24979276 ┆           ┆ Défense   ┆ se        ┆   ┆         ┆           ┆           ┆           │
# │ 9…         ┆           ┆           ┆           ┆   ┆         ┆           ┆           ┆           │
# └────────────┴───────────┴───────────┴───────────┴───┴─────────┴───────────┴───────────┴───────────┘

# %%
#Cast variables for join
stations_geometry = stations.geometry.copy()
stations_pl = pl.from_pandas(stations.drop(columns="geometry"))

df_asc_counts = df_asc_counts.with_columns(
    pl.col("zdcid").cast(pl.Utf8)
)

print('df_asc_counts')
print(df_asc_counts.select('zdcid').head())

stations_pl = stations_pl.with_columns(
    pl.col("id_ref_zdc")
    .cast(pl.Float64, strict=False)   # 1) cast to float
    .cast(pl.Int64,   strict=False)   # 2) cast to int
    .cast(pl.Utf8,    strict=False)   # 3) cast to string
)
print('stations')
print(stations_pl.select('id_ref_zdc').head())
# Out:
# df_asc_counts
# shape: (5, 1)
# ┌───────┐
# │ zdcid │
# │ ---   │
# │ str   │
# ╞═══════╡
# │ 67625 │
# │ 70133 │
# │ 72287 │
# │ 71828 │
# │ 68129 │
# └───────┘
# stations
# shape: (5, 1)
# ┌────────────┐
# │ id_ref_zdc │
# │ ---        │
# │ str        │
# ╞════════════╡
# │ 71432      │
# │ 73669      │
# │ 72491      │
# │ 71030      │
# │ 71632      │
# └────────────┘

# %%
joined_pl = stations_pl.join(
    df_asc_counts,
    left_on="id_ref_zdc",
    right_on="zdcid",
    how="left"
)
joined_gdf = gpd.GeoDataFrame(joined_pl.to_pandas(), geometry=stations_geometry)

# %%
joined_gdf
# Out:
#                                geo_point_2d id_ref_zdc               nom_zda  \
# 0    48.884594208027806, 2.3379497756920697      71432              Abbesses
# 1      48.872097029931695, 2.40862005517699      73669      Adrienne Bolland
# 2      48.90808243782026, 2.377741481106109      72491          Aimé Césaire
# 3     48.82818847631351, 2.3271646496078247      71030                Alésia
# 4     48.843700739992194, 2.410109555597318      71632  Alexandra David-Néel
# ..                                      ...        ...                   ...
# 585    48.84734036417028, 2.432434660260661      71651             Vincennes
# 586     48.80020939834459, 2.40271281718153      70313       Vitry-sur-Seine
# 587   48.84150552236008, 2.3079486779742893      71113           Volontaires
# 588   48.85787849486676, 2.3800206442479825      71750              Voltaire
# 589    48.88380920123339, 2.304674440528396      71423                Wagram
#
#           station_clean   res_com     mode exploitant ligne  \
# 0              abbesses  METRO 12    METRO       RATP  None
# 1       adriennebolland   TRAM 3b  TRAMWAY       RATP  None
# 2           aimécésaire  METRO 12    METRO       RATP  None
# 3                alésia   METRO 4    METRO       RATP  None
# 4    alexandradavidnéel   TRAM 3a  TRAMWAY       RATP  None
# ..                  ...       ...      ...        ...   ...
# 585           vincennes     RER A      RER       RATP  None
# 586       vitrysurseine     RER C      RER       SNCF  None
# 587         volontaires  METRO 12    METRO       RATP  None
# 588            voltaire   METRO 9    METRO       RATP  None
# 589              wagram   METRO 3    METRO       RATP  None
#
#                   station facilite_acces_code  \
# 0                Abbesses              yellow
# 1        Adrienne Bolland               green
# 2            Aimé Césaire               black
# 3                  Alésia              yellow
# 4    Alexandra David-Néel               green
# ..                    ...                 ...
# 585             Vincennes               green
# 586       Vitry-sur-Seine               green
# 587           Volontaires               white
# 588              Voltaire              yellow
# 589                Wagram              yellow
#
#                                         facilite_acces  \
# 0    équipée d'au moins un escalator ou ascenseur s...
# 1        très facile d'accès (ascenseur ou plain-pied)
# 2    facile d'accès, équipée d'escalator ou ascense...
# 3    équipée d'au moins un escalator ou ascenseur s...
# 4        très facile d'accès (ascenseur ou plain-pied)
# ..                                                 ...
# 585      très facile d'accès (ascenseur ou plain-pied)
# 586      très facile d'accès (ascenseur ou plain-pied)
# 587  comportant uniquement des escaliers et peu pro...
# 588  équipée d'au moins un escalator ou ascenseur s...
# 589  équipée d'au moins un escalator ou ascenseur s...
#
#      nombre_facilite_acces_station   id_zdc  total_validation  \
# 0                                1  71432.0       135006480.0
# 1                                1     None               NaN
# 2                                1  72491.0       138602792.0
# 3                                1  71030.0       136235540.0
# 4                                1     None               NaN
# ..                             ...      ...               ...
# 585                              1  71651.0       137354967.0
# 586                              1  70313.0       133313448.0
# 587                              1  71113.0       135683604.0
# 588                              1  71750.0       135894500.0
# 589                              1  71423.0       136846468.0
#
#      total_validation_amethyste  pct_amethyste  n_lifts  \
# 0                    19286640.0        14.2857      2.0
# 1                           NaN            NaN      NaN
# 2                    19862534.0        14.3305      3.0
# 3                    19462220.0        14.2857      NaN
# 4                           NaN            NaN      NaN
# ..                          ...            ...      ...
# 585                  19632374.0        14.2932      2.0
# 586                  19265762.0        14.4515      2.0
# 587                  19484962.0        14.3606      NaN
# 588                  19372500.0        14.2555      NaN
# 589                  19569902.0        14.3006      NaN
#
#                      geometry
# 0    POINT (48.88459 2.33795)
# 1     POINT (48.8721 2.40862)
# 2    POINT (48.90808 2.37774)
# 3    POINT (48.82819 2.32716)
# 4     POINT (48.8437 2.41011)
# ..                        ...
# 585  POINT (48.84734 2.43243)
# 586  POINT (48.80021 2.40271)
# 587  POINT (48.84151 2.30795)
# 588  POINT (48.85788 2.38002)
# 589  POINT (48.88381 2.30467)
#
# [590 rows x 18 columns]

# %%
match_col = "n_lifts"   # typically the join key is good

matched_count = joined_pl.filter(
    pl.col(match_col).is_not_null()
).count()

not_matched_count = joined_pl.filter(
    pl.col(match_col).is_null()
).count()

total = joined_pl.count()

matched_count, not_matched_count, total
# Out:
# (shape: (1, 29)
#  ┌────────────┬────────────┬─────────┬────────────┬───┬───────────┬─────────┬──────────┬────────────┐
#  │ geo_point_ ┆ id_ref_zdc ┆ nom_zda ┆ station_cl ┆ … ┆ liftstate ┆ zdcname ┆ liftmode ┆ centroidzd │
#  │ 2d         ┆ ---        ┆ ---     ┆ ean        ┆   ┆ ---       ┆ ---     ┆ ---      ┆ c          │
#  │ ---        ┆ u32        ┆ u32     ┆ ---        ┆   ┆ u32       ┆ u32     ┆ u32      ┆ ---        │
#  │ u32        ┆            ┆         ┆ u32        ┆   ┆           ┆         ┆          ┆ u32        │
#  ╞════════════╪════════════╪═════════╪════════════╪═══╪═══════════╪═════════╪══════════╪════════════╡
#  │ 678        ┆ 678        ┆ 678     ┆ 678        ┆ … ┆ 675       ┆ 678     ┆ 678      ┆ 678        │
#  └────────────┴────────────┴─────────┴────────────┴───┴───────────┴─────────┴──────────┴────────────┘,
#  shape: (1, 29)
#  ┌────────────┬────────────┬─────────┬────────────┬───┬───────────┬─────────┬──────────┬────────────┐
#  │ geo_point_ ┆ id_ref_zdc ┆ nom_zda ┆ station_cl ┆ … ┆ liftstate ┆ zdcname ┆ liftmode ┆ centroidzd │
#  │ 2d         ┆ ---        ┆ ---     ┆ ean        ┆   ┆ ---       ┆ ---     ┆ ---      ┆ c          │
#  │ ---        ┆ u32        ┆ u32     ┆ ---        ┆   ┆ u32       ┆ u32     ┆ u32      ┆ ---        │
#  │ u32        ┆            ┆         ┆ u32        ┆   ┆           ┆         ┆          ┆ u32        │
#  ╞════════════╪════════════╪═════════╪════════════╪═══╪═══════════╪═════════╪══════════╪════════════╡
#  │ 412        ┆ 412        ┆ 412     ┆ 412        ┆ … ┆ 0         ┆ 0       ┆ 0        ┆ 0          │
#  └────────────┴────────────┴─────────┴────────────┴───┴───────────┴─────────┴──────────┴────────────┘,
#  shape: (1, 29)
#  ┌────────────┬────────────┬─────────┬────────────┬───┬───────────┬─────────┬──────────┬────────────┐
#  │ geo_point_ ┆ id_ref_zdc ┆ nom_zda ┆ station_cl ┆ … ┆ liftstate ┆ zdcname ┆ liftmode ┆ centroidzd │
#  │ 2d         ┆ ---        ┆ ---     ┆ ean        ┆   ┆ ---       ┆ ---     ┆ ---      ┆ c          │
#  │ ---        ┆ u32        ┆ u32     ┆ ---        ┆   ┆ u32       ┆ u32     ┆ u32      ┆ ---        │
#  │ u32        ┆            ┆         ┆ u32        ┆   ┆           ┆         ┆          ┆ u32        │
#  ╞════════════╪════════════╪═════════╪════════════╪═══╪═══════════╪═════════╪══════════╪════════════╡
#  │ 1090       ┆ 1090       ┆ 1090    ┆ 1090       ┆ … ┆ 675       ┆ 678     ┆ 678      ┆ 678        │
#  └────────────┴────────────┴─────────┴────────────┴───┴───────────┴─────────┴──────────┴────────────┘)
